# %% [markdown]
# # **Predicting House Prices using the Boston Housing Dataset**

# %% [markdown]
# ## **1. Objective Setting**

# %% [markdown]
# ### 1.1. Introduction
# **To help people to know how much money to get house in Boston**
#
# According to the real estate agency "Centry 21 Global", information is provided so that the location, type of real estate, price, bedroom, bathroom, size, etc. can be taken into consideration when trading a house. On May 25, 2022, it was found that the range ranged from 4,200,000 USD to 1,850 USD on a connection date basis, and that even for similar priced items, the prices would vary slightly depending on the details and location.
# Also, in contrast to many people who predicted that real estate prices would fall due to lifestyle changes since Corona, they have been steadily rising since May 2020, rather than living with rental fees. However, the number of people trying to buy a house on this occasion has increased.
# According to the Greater Boston Real Estate Brokers Association's Monthly Home Price Trends Report in June 2021, average single-family home prices in May rose 20% compared to 2019, and condominium prices rose 7.2%. It is said that such a large rise in house prices has led to a decrease in the number of consumers who are trying to buy a house by putting pressure on the buying psychology of buyers.

# %% [markdown]
# ### 1.2. Objective
# **Therefore**, in this report, in the preparatory process for creating a model for predicting rent in Boston, we will use the data of houses traded from January 2006 to July 2010 to create a rent prediction model. Let's make it and proceed to the prediction. At this time, there are 81 columns in the data for training, of which 10 columns that most affect the prediction of the collected value are selected to create a model, and the model is used. Advance the forecast.

# %% [markdown]
# ### 1.3. Reference
# * CENTURY 21 Global - https://www.century21global.com/ko/for-sale-residential/USA/MA/BOSTON?sort=priceDesc&pageNo=2
# * Boston Dream - http://bostondreamrealty.com/ko/%eb%b3%b4%ec%8a%a4%ed%84%b4-%eb%b6%80%eb%8f%99%ec%82%b0-%ea%b5%ac%ec%9e%85
# * Boston Korea - https://www.bostonkorea.com/news.php?code=foto&mode=view&num=32017

# %% [markdown]
# ## **2. Data Curation**

# %% [markdown]
# ### 2.1. Boston Housing Price
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
#
# * Using two file : train.csv, test.csv
# * When a model is made with train data and actual prediction using the model is made, housing prices are predicted using test data.

# %% [markdown]
# ### 2.2. Data size
# * train.csv -> 1460 rows x 81 columns
# * test.csv -> 1459 rows x 80 columns

# %% [markdown]
# ### 2.3. Columns Description
# * Characteristics of House Structure.
# * Characteristics of the terrain around the house.
# * The specific characteristics of a house
#     * Each row represents a set of data for an individual house.
#     * One row represents one sample (housing), and corresponding data is input according to each column.
# * SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.

# %% [markdown]
# There are 81 columns, but we use 10 columns that predict SalePrice best.
# * MSSubClass (numerical) : The building class
# * MSZoning (categorical) : The general zoning classification
# * LotFrontage (numerical) : Linear feet of street connected to property
# * LotArea (numerical) : Lot size in square feet
# * Street (categorical) : Type of road access
# * Alley (categorical): Type of alley access
# * LotShape (categorical): General shape of property
# * LandConour (categorical): Flatness of the property
# * Utilities (categorical): Type of utilities available
# * LotConfig (categorical): Lot configuration
# * LandSlope (categorical): Slope of property
# * Neighborhood (categorical): Physical locations within Ames city limits
# * Condition1 (categorical): Proximity to main road or railroad
# * Condition2 (categorical): Proximity to main road or railroad (if a second is present)
# * BldgType (categorical): Type of dwelling
# * HouseStyle (categorical): Style of dwelling
# * OverallQual (numerical) : Overall material and finish quality
# * OverallCond (numerical) : Overall condition rating
# * YearBuilt (numerical) : Original construction date
# * YearRemodAdd (numerical) : Remodel date
# * RoofStyle (categorical): Type of roof
# * RoofMatl (categorical): Roof material
# * Exterior1st (categorical): Exterior covering on house
# * Exterior2nd (categorical): Exterior covering on house (if more than one material)
# * MasVnrType (categorical): Masonry veneer type
# * MasVnrArea (numerical) : Masonry veneer area in square feet
# * ExterQual (categorical): Exterior material quality
# * ExterCond (categorical): Present condition of the material on the exterior
# * Foundation (categorical): Type of foundation
# * BsmtQual (categorical): Height of the basement
# * BsmtCond (categorical): General condition of the basement
# * BsmtExposure (categorical): Walkout or garden level basement walls
# * BsmtFinType1 (categorical): Quality of basement finished area
# * BsmtFinSF1 (numerical) : Type 1 finished square feet
# * BsmtFinType2 (categorical): Quality of second finished area (if present)
# * BsmtFinSF2 (numerical) : Type 2 finished square feet
# * BsmtUnfSF (numerical) : Unfinished square feet of basement area
# * TotalBsmtSF (numerical) : Total square feet of basement area
# * Heating (categorical): Type of heating
# * HeatingQC (categorical): Heating quality and condition
# * CentralAir (categorical): Central air conditioning
# * Electrical (categorical): Electrical system
# * 1stFlrSF (numerical) : First Floor square feet
# * 2ndFlrSF (numerical) : Second floor square feet
# * LowQualFinSF (numerical) : Low quality finished square feet (all floors)
# * GrLivArea (numerical) : Above grade (ground) living area square feet
# * BsmtFullBath (numerical) : Basement full bathrooms
# * BsmtHalfBath (numerical) : Basement half bathrooms
# * FullBath (numerical) : Full bathrooms above grade
# * HalfBath (numerical) : Half baths above grade
# * Bedroom (numerical) : Number of bedrooms above basement level
# * Kitchen (numerical) : Number of kitchens
# * KitchenQual (categorical): Kitchen quality
# * TotRmsAbvGrd (numerical) : Total rooms above grade (does not include bathrooms)
# * Functional (categorical): Home functionality rating
# * Fireplaces (numerical) : Number of fireplaces
# * FireplaceQu (categorical): Fireplace quality
# * GarageType (categorical): Garage location
# * GarageYrBlt (numerical) : Year garage was built
# * GarageFinish (categorical): Interior finish of the garage
# * GarageCars (numerical) : Size of garage in car capacity
# * GarageArea (numerical) : Size of garage in square feet
# * GarageQual (categorical): Garage quality
# * GarageCond (categorical): Garage condition
# * PavedDrive (categorical): Paved driveway
# * WoodDeckSF (numerical) : Wood deck area in square feet
# * OpenPorchSF (numerical) : Open porch area in square feet
# * EnclosedPorch (numerical) : Enclosed porch area in square feet
# * 3SsnPorch (numerical) : Three season porch area in square feet
# * ScreenPorch (numerical) : Screen porch area in square feet
# * PoolArea (numerical) : Pool area in square feet
# * PoolQC (categorical): Pool quality
# * Fence  (categorical): Fence quality
# * MiscFeature (categorical): Miscellaneous feature not covered in other categories
# * MiscVa (numerical) l: $Value of miscellaneous feature
# * MoSold (numerical) : Month Sold
# * YrSold (numerical) : Year Sold
# * SaleType (categorical): Type of sale
# * SaleCondition (categorical): Condition of sale
# * **SalePrice (numerical): the property's sale price in dollars. This is the target variable that you're trying to predict**

# %% [markdown]
# ## **3. Data Inspection**

# %% [markdown]
# ### 3.1. Import Libraries / Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

import missingno as msno
from scipy import stats
from scipy.stats import norm
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, Lasso, ElasticNet
from xgboost import XGBRegressor
from lightgbm import  LGBMRegressor
import statsmodels.api as sm
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.metrics import make_scorer, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### **missingno**
# missingno library is for missing data visualizations and utilities that allows to get a quick visual summary of the comleteness of dataset.
# To get started, type "pip install missingno" into your console.
# To import this library, type "import missingno as msno" into your code.
# Most of the developers uses missingno as msno for short.
# #### matrix
# One of the methods in missingno is matrix.
# It used as msno.matrix(DataFrame)
# It displays data-dense about missing values.

# %%
# Data Load : train and test set

train=pd.read_csv('/content/train.csv')
test=pd.read_csv('/content/test.csv')

print("[Train]")
print(train.shape) # Train Set에는 SalePrice(target) 이 포함
print() 
print("[Test]")
print(test.shape)  # Test Set에는 target 제외여서 80 columns
# Out:
# [Train]
# (1460, 81)
#
# [Test]
# (1459, 80)

# %% [markdown]
# ### 3.2. Original Dataset

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ### 3.3. DataFrame

# %% [markdown]
# * Original Dataset has 81 columns.
# * To display all columns and statistics, the data frame is divided into 10 columns each.

# %% [markdown]
# #### 3.3.1. DataFrame 1

# %%
df = pd.read_csv("/content/train.csv")
df.drop(axis=1, labels='Id', inplace=True)

df1 = df.iloc[:, 0:10]
df1
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig
# 0            Lvl    AllPub    Inside
# 1            Lvl    AllPub       FR2
# ...

# %%
df1.dtypes
# Out:
# MSSubClass       int64
# MSZoning        object
# LotFrontage    float64
# LotArea          int64
# Street          object
# Alley           object
# LotShape        object
# LandContour     object
# Utilities       object
# LotConfig       object
# dtype: object

# %%
df1.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea
# count  1460.000000  1201.000000    1460.000000
# mean     56.897260    70.049958   10516.828082
# std      42.300571    24.284752    9981.264932
# min      20.000000    21.000000    1300.000000
# 25%      20.000000    59.000000    7553.500000
# 50%      50.000000    69.000000    9478.500000
# 75%      70.000000    80.000000   11601.500000
# max     190.000000   313.000000  215245.000000

# %%
df1[['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig']].describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052

# %%
msno.matrix(df1)

# %% [markdown]
# #### 3.3.2. DataFrame 2

# %%
df2 = df.iloc[:, 10:20]
df2
# Out:
#      LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0          Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1          Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2          Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3          Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4          Gtl      NoRidge       Norm       Norm     1Fam     2Story
# ...        ...          ...        ...        ...      ...        ...
# 1455       Gtl      Gilbert       Norm       Norm     1Fam     2Story
# 1456       Gtl       NWAmes       Norm       Norm     1Fam     1Story
# 1457       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 1458       Gtl        NAmes       Norm       Norm     1Fam     1Story
# 1459       Gtl      Edwards       Norm       Norm     1Fam     1Story
#
#       OverallQual  OverallCond  YearBuilt  YearRemodAdd
# 0               7            5       2003          2003
# ...

# %%
df2.dtypes
# Out:
# LandSlope       object
# Neighborhood    object
# Condition1      object
# Condition2      object
# BldgType        object
# HouseStyle      object
# OverallQual      int64
# OverallCond      int64
# YearBuilt        int64
# YearRemodAdd     int64
# dtype: object

# %%
df2.describe()
# Out:
#        OverallQual  OverallCond    YearBuilt  YearRemodAdd
# count  1460.000000  1460.000000  1460.000000   1460.000000
# mean      6.099315     5.575342  1971.267808   1984.865753
# std       1.382997     1.112799    30.202904     20.645407
# min       1.000000     1.000000  1872.000000   1950.000000
# 25%       5.000000     5.000000  1954.000000   1967.000000
# 50%       6.000000     5.000000  1973.000000   1994.000000
# 75%       7.000000     6.000000  2000.000000   2004.000000
# max      10.000000     9.000000  2010.000000   2010.000000

# %%
df2[['LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle']].describe()
# Out:
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle
# count       1460         1460       1460       1460     1460       1460
# unique         3           25          9          8        5          8
# top          Gtl        NAmes       Norm       Norm     1Fam     1Story
# freq        1382          225       1260       1445     1220        726

# %%
msno.matrix(df2)

# %% [markdown]
# #### 3.3.3. DataFrame 3

# %%
df3 = df.iloc[:, 20:30]
df3
# Out:
#      RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea  \
# 0        Gable  CompShg     VinylSd     VinylSd    BrkFace       196.0
# 1        Gable  CompShg     MetalSd     MetalSd       None         0.0
# 2        Gable  CompShg     VinylSd     VinylSd    BrkFace       162.0
# 3        Gable  CompShg     Wd Sdng     Wd Shng       None         0.0
# 4        Gable  CompShg     VinylSd     VinylSd    BrkFace       350.0
# ...        ...      ...         ...         ...        ...         ...
# 1455     Gable  CompShg     VinylSd     VinylSd       None         0.0
# 1456     Gable  CompShg     Plywood     Plywood      Stone       119.0
# 1457     Gable  CompShg     CemntBd     CmentBd       None         0.0
# 1458       Hip  CompShg     MetalSd     MetalSd       None         0.0
# 1459     Gable  CompShg     HdBoard     HdBoard       None         0.0
#
#      ExterQual ExterCond Foundation BsmtQual
# 0           Gd        TA      PConc       Gd
# ...

# %%
df3.dtypes
# Out:
# RoofStyle       object
# RoofMatl        object
# Exterior1st     object
# Exterior2nd     object
# MasVnrType      object
# MasVnrArea     float64
# ExterQual       object
# ExterCond       object
# Foundation      object
# BsmtQual        object
# dtype: object

# %%
df3.describe()
# Out:
#         MasVnrArea
# count  1452.000000
# mean    103.685262
# std     181.066207
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%     166.000000
# max    1600.000000

# %%
df3[['RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual']].describe()
# Out:
#        RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# count       1460     1460        1460        1460       1452      1460
# unique         6        8          15          16          4         4
# top        Gable  CompShg     VinylSd     VinylSd       None        TA
# freq        1141     1434         515         504        864       906
#
#        ExterCond Foundation BsmtQual
# count       1460       1460     1423
# unique         5          6        4
# top           TA      PConc       TA
# freq        1282        647      649

# %%
msno.matrix(df3)

# %% [markdown]
# #### 3.3.4. DataFrame 4

# %%
df4 = df.iloc[:, 30:40]
df4
# Out:
#      BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0          TA           No          GLQ         706          Unf           0
# 1          TA           Gd          ALQ         978          Unf           0
# 2          TA           Mn          GLQ         486          Unf           0
# 3          Gd           No          ALQ         216          Unf           0
# 4          TA           Av          GLQ         655          Unf           0
# ...       ...          ...          ...         ...          ...         ...
# 1455       TA           No          Unf           0          Unf           0
# 1456       TA           No          ALQ         790          Rec         163
# 1457       Gd           No          GLQ         275          Unf           0
# 1458       TA           Mn          GLQ          49          Rec        1029
# 1459       TA           No          BLQ         830          LwQ         290
#
# ...

# %%
df4.dtypes
# Out:
# BsmtCond        object
# BsmtExposure    object
# BsmtFinType1    object
# BsmtFinSF1       int64
# BsmtFinType2    object
# BsmtFinSF2       int64
# BsmtUnfSF        int64
# TotalBsmtSF      int64
# Heating         object
# HeatingQC       object
# dtype: object

# %%
df4.describe()
# Out:
#         BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF
# count  1460.000000  1460.000000  1460.000000  1460.000000
# mean    443.639726    46.549315   567.240411  1057.429452
# std     456.098091   161.319273   441.866955   438.705324
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000   223.000000   795.750000
# 50%     383.500000     0.000000   477.500000   991.500000
# 75%     712.250000     0.000000   808.000000  1298.250000
# max    5644.000000  1474.000000  2336.000000  6110.000000

# %%
df4[['BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC']].describe()
# Out:
#        BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 Heating HeatingQC
# count      1423         1422         1423         1422    1460      1460
# unique        4            4            6            6       6         5
# top          TA           No          Unf          Unf    GasA        Ex
# freq       1311          953          430         1256    1428       741

# %%
msno.matrix(df4)

# %% [markdown]
# #### 3.3.5. DataFrame 5

# %%
df5 = df.iloc[:, 40:50]
df5
# Out:
#      CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0             Y      SBrkr       856       854             0       1710
# 1             Y      SBrkr      1262         0             0       1262
# 2             Y      SBrkr       920       866             0       1786
# 3             Y      SBrkr       961       756             0       1717
# 4             Y      SBrkr      1145      1053             0       2198
# ...         ...        ...       ...       ...           ...        ...
# 1455          Y      SBrkr       953       694             0       1647
# 1456          Y      SBrkr      2073         0             0       2073
# 1457          Y      SBrkr      1188      1152             0       2340
# 1458          Y      FuseA      1078         0             0       1078
# 1459          Y      SBrkr      1256         0             0       1256
#
#       BsmtFullBath  BsmtHalfBath  FullBath  HalfBath
# ...

# %%
df5.dtypes
# Out:
# CentralAir      object
# Electrical      object
# 1stFlrSF         int64
# 2ndFlrSF         int64
# LowQualFinSF     int64
# GrLivArea        int64
# BsmtFullBath     int64
# BsmtHalfBath     int64
# FullBath         int64
# HalfBath         int64
# dtype: object

# %%
df5.describe()
# Out:
#           1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  BsmtFullBath  \
# count  1460.000000  1460.000000   1460.000000  1460.000000   1460.000000
# mean   1162.626712   346.992466      5.844521  1515.463699      0.425342
# std     386.587738   436.528436     48.623081   525.480383      0.518911
# min     334.000000     0.000000      0.000000   334.000000      0.000000
# 25%     882.000000     0.000000      0.000000  1129.500000      0.000000
# 50%    1087.000000     0.000000      0.000000  1464.000000      0.000000
# 75%    1391.250000   728.000000      0.000000  1776.750000      1.000000
# max    4692.000000  2065.000000    572.000000  5642.000000      3.000000
#
#        BsmtHalfBath     FullBath     HalfBath
# count   1460.000000  1460.000000  1460.000000
# mean       0.057534     1.565068     0.382877
# std        0.238753     0.550916     0.502885
# min        0.000000     0.000000     0.000000
# 25%        0.000000     1.000000     0.000000
# ...

# %%
df5[['CentralAir', 'Electrical']].describe()
# Out:
#        CentralAir Electrical
# count        1460       1459
# unique          2          5
# top             Y      SBrkr
# freq         1365       1334

# %%
msno.matrix(df5)

# %% [markdown]
# #### 3.3.6. DataFrame 6

# %%
df6 = df.iloc[:, 50:60]
df6
# Out:
#       BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  \
# 0                3             1          Gd             8        Typ
# 1                3             1          TA             6        Typ
# 2                3             1          Gd             6        Typ
# 3                3             1          Gd             7        Typ
# 4                4             1          Gd             9        Typ
# ...            ...           ...         ...           ...        ...
# 1455             3             1          TA             7        Typ
# 1456             3             1          TA             7       Min1
# 1457             4             1          Gd             9        Typ
# 1458             2             1          Gd             5        Typ
# 1459             3             1          TA             6        Typ
#
#       Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish
# ...

# %%
df6.dtypes
# Out:
# BedroomAbvGr      int64
# KitchenAbvGr      int64
# KitchenQual      object
# TotRmsAbvGrd      int64
# Functional       object
# Fireplaces        int64
# FireplaceQu      object
# GarageType       object
# GarageYrBlt     float64
# GarageFinish     object
# dtype: object

# %%
df6.describe()
# Out:
#        BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  GarageYrBlt
# count   1460.000000   1460.000000   1460.000000  1460.000000  1379.000000
# mean       2.866438      1.046575      6.517808     0.613014  1978.506164
# std        0.815778      0.220338      1.625393     0.644666    24.689725
# min        0.000000      0.000000      2.000000     0.000000  1900.000000
# 25%        2.000000      1.000000      5.000000     0.000000  1961.000000
# 50%        3.000000      1.000000      6.000000     1.000000  1980.000000
# 75%        3.000000      1.000000      7.000000     1.000000  2002.000000
# max        8.000000      3.000000     14.000000     3.000000  2010.000000

# %%
df6[['KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish']].describe()
# Out:
#        KitchenQual Functional FireplaceQu GarageType GarageFinish
# count         1460       1460         770       1379         1379
# unique           4          7           5          6            3
# top             TA        Typ          Gd     Attchd          Unf
# freq           735       1360         380        870          605

# %%
msno.matrix(df6)

# %% [markdown]
# #### 3.3.7. DataFrame 7

# %%
df7 = df.iloc[:, 60:70]
df7
# Out:
#       GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  \
# 0              2         548         TA         TA          Y           0
# 1              2         460         TA         TA          Y         298
# 2              2         608         TA         TA          Y           0
# 3              3         642         TA         TA          Y           0
# 4              3         836         TA         TA          Y         192
# ...          ...         ...        ...        ...        ...         ...
# 1455           2         460         TA         TA          Y           0
# 1456           2         500         TA         TA          Y         349
# 1457           1         252         TA         TA          Y           0
# 1458           1         240         TA         TA          Y         366
# 1459           1         276         TA         TA          Y         736
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch
# ...

# %%
df7.dtypes
# Out:
# GarageCars        int64
# GarageArea        int64
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# WoodDeckSF        int64
# OpenPorchSF       int64
# EnclosedPorch     int64
# 3SsnPorch         int64
# ScreenPorch       int64
# dtype: object

# %%
df7.describe()
# Out:
#         GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# count  1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean      1.767123   472.980137    94.244521    46.660274      21.954110
# std       0.747315   213.804841   125.338794    66.256028      61.119149
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%       1.000000   334.500000     0.000000     0.000000       0.000000
# 50%       2.000000   480.000000     0.000000    25.000000       0.000000
# 75%       2.000000   576.000000   168.000000    68.000000       0.000000
# max       4.000000  1418.000000   857.000000   547.000000     552.000000
#
#          3SsnPorch  ScreenPorch
# count  1460.000000  1460.000000
# mean      3.409589    15.060959
# std      29.317331    55.757415
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     0.000000
# max     508.000000   480.000000

# %%
df7[['GarageQual', 'GarageCond', 'PavedDrive']].describe()
# Out:
#        GarageQual GarageCond PavedDrive
# count        1379       1379       1460
# unique          5          5          3
# top            TA         TA          Y
# freq         1311       1326       1340

# %%
msno.matrix(df7)

# %% [markdown]
# #### 3.3.8. DataFrame 8

# %%
df8 = df.iloc[:, 70:]
df8
# Out:
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0    NaN    NaN         NaN        0       2    2008       WD
# 1            0    NaN    NaN         NaN        0       5    2007       WD
# 2            0    NaN    NaN         NaN        0       9    2008       WD
# 3            0    NaN    NaN         NaN        0       2    2006       WD
# 4            0    NaN    NaN         NaN        0      12    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1455         0    NaN    NaN         NaN        0       8    2007       WD
# 1456         0    NaN  MnPrv         NaN        0       2    2010       WD
# 1457         0    NaN  GdPrv        Shed     2500       5    2010       WD
# 1458         0    NaN    NaN         NaN        0       4    2010       WD
# 1459         0    NaN    NaN         NaN        0       6    2008       WD
#
#      SaleCondition  SalePrice
# 0           Normal     208500
# ...

# %%
df8.dtypes
# Out:
# PoolArea          int64
# PoolQC           object
# Fence            object
# MiscFeature      object
# MiscVal           int64
# MoSold            int64
# YrSold            int64
# SaleType         object
# SaleCondition    object
# SalePrice         int64
# dtype: object

# %%
df8.describe()
# Out:
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000

# %%
df8[['PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']].describe()
# Out:
#        PoolQC  Fence MiscFeature SaleType SaleCondition
# count       7    281          54     1460          1460
# unique      3      4           4        9             6
# top        Gd  MnPrv        Shed       WD        Normal
# freq        3    157          49     1267          1198

# %%
msno.matrix(df8)

# %% [markdown]
# ### 3.3. Note
# * Since there are too many features, we plan to select best features and take a plot.

# %% [markdown]
# ### 3.4. Concat Train Dataset and Test Dataset

# %%
#outlier

fix, ax=plt.subplots()
ax.scatter(x=train['GrLivArea'], y=train['SalePrice'])
plt.ylabel('SalePrice') # 생활 면적(우리나라로 치면 몇 평인지)
plt.xlabel('GrLivArea')
plt.show()

# %%
train = train.drop(train[(train['GrLivArea']>4000) & (train['SalePrice']<300000)].index)
print('[After Feature Engineering]\n')
print(train) # 2개의 outlier 제거
# Out:
# [After Feature Engineering]
#
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# *   After drop outlier, 1460 rows are now 1458 rows

# %%
fe_name=list(test)
df_train=train[fe_name]
df=pd.concat((df_train, test))
print('[DataFrame]')
print(df.shape)
# Out:
# [DataFrame]
# (2917, 80)

# %%
''' 4. Target Attribute 확인 '''
from scipy import stats
from scipy.stats import norm

sns.distplot(train['SalePrice'], fit=norm) # 정규분포를 따르고 있는지 보기 위한 출력
plt.show()

# %%
train['SalePrice'] = np.log1p(train["SalePrice"]) # 정규분포에 가깝게 만들기 위해 log 취함
sns.distplot(train['SalePrice'],fit=norm)
plt.show()

# %%
target=train['SalePrice']

# %% [markdown]
# ## **4. Data Preparation**

# %% [markdown]
# ### 4.1. Drop missing values

# %%
null_df = (df.isna().sum() / len(df)) *100
null_df = null_df.drop(null_df[null_df == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :null_df})
print('[Missing data]')
print(missing_data.head(20))
# Out:
# [Missing data]
#               Missing Ratio
# PoolQC            99.691464
# MiscFeature       96.400411
# Alley             93.212204
# Fence             80.425094
# FireplaceQu       48.680151
# LotFrontage       16.660953
# GarageFinish       5.450806
# GarageQual         5.450806
# GarageCond         5.450806
# GarageYrBlt        5.450806
# GarageType         5.382242
# BsmtExposure       2.811107
# BsmtCond           2.811107
# BsmtQual           2.776826
# BsmtFinType2       2.742544
# BsmtFinType1       2.708262
# MasVnrType         0.822763
# MasVnrArea         0.788481
# MSZoning           0.137127
# BsmtFullBath       0.068564

# %%
f, ax = plt.subplots(figsize=(15, 12))
plt.xticks(rotation='90')
sns.barplot(x=null_df.index, y=null_df) 
plt.show()

# %% [markdown]
# *  Filled with missing values for each attribute.

# %%
df["PoolQC"] = df["PoolQC"].fillna("None")
df["MiscFeature"] = df["MiscFeature"].fillna("None")
df["Alley"] = df["Alley"].fillna("None")
df["Fence"] = df["Fence"].fillna("None")
df["FireplaceQu"] = df["FireplaceQu"].fillna("None")
df['MSSubClass'] = df['MSSubClass'].fillna("None")
df["MasVnrType"] = df["MasVnrType"].fillna("None")
df["LotFrontage"] = df.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))
for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    df[col] = df[col].fillna('None')
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    df[col] = df[col].fillna('None') 
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'): 
    df[col] = df[col].fillna(0) 
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    df[col] = df[col].fillna(0)
df["MasVnrArea"] = df["MasVnrArea"].fillna(0)
df['MSZoning'] = df['MSZoning'].fillna(df['MSZoning'].mode()[0]) 
df["Functional"] = df["Functional"].fillna("Typ")
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0]) 
df['KitchenQual'] = df['KitchenQual'].fillna(df['KitchenQual'].mode()[0]) 
df['Exterior1st'] = df['Exterior1st'].fillna(df['Exterior1st'].mode()[0])
df['Exterior2nd'] = df['Exterior2nd'].fillna(df['Exterior2nd'].mode()[0])
df['SaleType'] = df['SaleType'].fillna(df['SaleType'].mode()[0])

print('[Utilities]')
print(df['Utilities'])
df = df.drop(['Utilities'], axis=1) # 99% value is Allpub -> Drop
# Out:
# [Utilities]
# 0       AllPub
# 1       AllPub
# 2       AllPub
# 3       AllPub
# 4       AllPub
#          ...
# 1454    AllPub
# 1455    AllPub
# 1456    AllPub
# 1457    AllPub
# 1458    AllPub
# Name: Utilities, Length: 2917, dtype: object

# %%
null_df = (df.isna().sum() / len(df)) *100 
null_df = null_df.drop(null_df[null_df == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :null_df})
print('[Missing data]')
print(missing_data.head(20))
# Out:
# [Missing data]
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %% [markdown]
# ### 4.2. Numarical values and Categorical values

# %% [markdown]
# * Divide Numeric and Categorical

# %%
df_obj = df.select_dtypes(include='object')
print('[Categorical]')
print(df_obj)
li_obj = list(df_obj.columns)
print('[li_obj]')
print(li_obj)

df_num = df.select_dtypes(exclude = 'object')
print('[Numeric]')
print(df_num)
li_num = list(df_num.columns)
print('[li_num]')
print(li_num)
# Out:
# [Categorical]
#      MSZoning Street Alley LotShape LandContour LotConfig LandSlope  \
# 0          RL   Pave  None      Reg         Lvl    Inside       Gtl
# 1          RL   Pave  None      Reg         Lvl       FR2       Gtl
# 2          RL   Pave  None      IR1         Lvl    Inside       Gtl
# 3          RL   Pave  None      IR1         Lvl    Corner       Gtl
# 4          RL   Pave  None      IR1         Lvl       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...
# 1454       RM   Pave  None      Reg         Lvl    Inside       Gtl
# 1455       RM   Pave  None      Reg         Lvl    Inside       Gtl
# 1456       RL   Pave  None      Reg         Lvl    Inside       Gtl
# 1457       RL   Pave  None      Reg         Lvl    Inside       Gtl
# 1458       RL   Pave  None      Reg         Lvl    Inside       Mod
#
#      Neighborhood Condition1 Condition2  ... GarageType GarageFinish  \
# ...

# %%
cols = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold')

for c in cols:
    lb = LabelEncoder() 
    lb.fit(list(df[c].values)) 
    df[c] = lb.transform(list(df[c].values))

# %% [markdown]
# *   Visualize Numerical Feature

# %%
row=11
col=3
fig, axs = plt.subplots(row,col, figsize = (col*3,row*4))
for r in range(0,row):
    for c in range(0,col):
        i = r*col + c
        if i < len(li_num):
            sns.regplot(train[li_num[i]],target , ax = axs[r][c])
plt.show()

# %% [markdown]
# *   Visualize Categorical features

# %%
row=12
col = 4 
fig, axs = plt.subplots(row,col, figsize = (col*4,row*3))

for r in range(0,row):
    for c in range(0,col):
        i = r*col + c
        if i < len(li_obj):
            sns.boxplot(train[li_obj[i]],target , ax = axs[r][c])
plt.show()

# %% [markdown]
# ### 4.3. Deal with Outliers

# %%
#find outliers
def outlier(df=None, col=None):
    #find the value located at 15%
    quantile_15 = np.quantile(df[col].values, 0.15)
    #find the value located at 85%.
    quantile_85 = np.quantile(df[col].values, 0.85)
    
    #find IQR
    IQR = quantile_85 - quantile_15
    
    #find a value that is 1.5 * IQR smaller than quantile_15
    minimum = quantile_15 - 1.5 * IQR
    #find a value that is 1.5 * IQR bigger than quantile_15.
    maximum = quantile_85 + 1.5 * IQR
    
    #store the values except for the outlier
    outlier_idx = df[col][ (df[col] < minimum) | (df[col] > maximum) ].index
    
    return outlier_idx
    

categorical_columns = ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 
                       'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 
                       'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 
                       'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 
                       'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 
                       'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 
                       'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 
                       'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 
                       'MiscFeature', 'SaleType', 'SaleCondition']

for col in df.columns:
    if col not in categorical_columns:
        outlier_idx = outlier(df=df, col=col)
        df.replace({col : outlier_idx}, {col : df[col].mean()})

df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1           5       RL         65.0     8450       1      1
# 1        2           0       RL         80.0     9600       1      1
# 2        3           5       RL         68.0    11250       1      1
# 3        4           6       RL         60.0     9550       1      1
# 4        5           5       RL         84.0    14260       1      1
# ...    ...         ...      ...          ...      ...     ...    ...
# 1454  2915          13       RM         21.0     1936       1      1
# 1455  2916          13       RM         21.0     1894       1      1
# 1456  2917           0       RL        160.0    20000       1      1
# 1457  2918           9       RL         62.0    10441       1      1
# 1458  2919           5       RL         74.0     9627       1      1
#
#       LotShape LandContour LotConfig  ...  ScreenPorch PoolArea PoolQC Fence  \
# ...

# %% [markdown]
# ### 4.4. Correlation and Heatmap

# %% [markdown]
# *   Correlation with target feature

# %%
cor=train.corr()
print('Correlation Feature -->\n', cor['SalePrice'])
cor_fe=cor.index[abs(cor['SalePrice'])>=0.3] # 0에 가까울 수록 No Relationship
print('Correlation Feature(above 0.3) -->\n', cor_fe)
# Out:
# Correlation Feature -->
#  Id              -0.017774
# MSSubClass      -0.073969
# LotFrontage      0.372900
# LotArea          0.260544
# OverallQual      0.821405
# OverallCond     -0.036821
# YearBuilt        0.587043
# YearRemodAdd     0.565992
# MasVnrArea       0.434621
# BsmtFinSF1       0.392283
# BsmtFinSF2       0.004863
# BsmtUnfSF        0.221892
# TotalBsmtSF      0.647563
# 1stFlrSF         0.620500
# 2ndFlrSF         0.319953
# LowQualFinSF    -0.037951
# GrLivArea        0.725211
# BsmtFullBath     0.237099
# BsmtHalfBath    -0.005124
# FullBath         0.595899
# HalfBath         0.314186
# BedroomAbvGr     0.209035
# KitchenAbvGr    -0.147534
# TotRmsAbvGrd     0.537702
# Fireplaces       0.491998
# GarageYrBlt      0.541638
# GarageCars       0.681033
# GarageArea       0.656129
# WoodDeckSF       0.334251
# OpenPorchSF      0.325215
# EnclosedPorch   -0.149029
# 3SsnPorch        0.054914
# ScreenPorch      0.121245
# PoolArea         0.074338
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(train[cor_fe].corr(), annot=True) # correlation이 0.3 이상인 feature만 히트맵으로 출력
plt.show()

# %% [markdown]
# ### 4.5. Feature Selection

# %%
df = pd.get_dummies(df)
print('[DataFrame Dummies]')
print(df.shape)

new_train = df[:train.shape[0]]
new_test = df[train.shape[0]:]
new_train = pd.concat([new_train, target], axis=1, sort=False)

corr_new_train = new_train.corr()
plt.figure(figsize=(5,15))
sns.heatmap(corr_new_train[['SalePrice']].sort_values(by=['SalePrice'], ascending=False).head(30),annot=True)
col_corr_dict = corr_new_train['SalePrice'].sort_values(ascending=False).to_dict()

best_columns = ["OverallQual", "GrLivArea", "GarageCars", "GarageArea", "TotalBsmtSF", "1stFlrSF", "FullBath", "YearBuilt", "YearRemodAdd", "Fireplaces"]

final_train = new_train[best_columns]
final_test = new_test[best_columns]
final_num = list(final_train.columns)
# Out:
# [DataFrame Dummies]
# (2917, 220)

# %% [markdown]
# ## **5. Data Analysis**

# %% [markdown]
# ### 5.1. Train & Test Set (Scaling)

# %%
features = ["GrLivArea", "MSSubClass", 'LotArea', 'TotRmsAbvGrd', 'OverallQual', 'YearBuilt','YrSold']

X_train, X_test, y_train, y_test = train_test_split(train[features], np.log(train["SalePrice"]), test_size=0.2, random_state = 42)

scaler = StandardScaler()
X_train_scale = scaler.fit_transform(X_train)
print("[Standard Scaler]")
print()
print("Before scale features Min value : \n ",format(X_train.min(axis=0)))
print("Before scale features Max value : \n ",format(X_train.max(axis=0)))
print("After scale features Min value : \n ",format(X_train_scale.min(axis=0)))
print("After scale features Max value : \n ",format(X_train_scale.max(axis=0)))
# Out:
# [Standard Scaler]
#
# Before scale features Min value :
#   GrLivArea        438
# MSSubClass        20
# LotArea         1300
# TotRmsAbvGrd       3
# OverallQual        1
# YearBuilt       1872
# YrSold          2006
# dtype: int64
# Before scale features Max value :
#   GrLivArea         4476
# MSSubClass         190
# LotArea         215245
# TotRmsAbvGrd        14
# OverallQual         10
# YearBuilt         2010
# YrSold            2010
# dtype: int64
# After scale features Min value :
#   [-2.12735101 -0.85740877 -0.87540807 -2.1954125  -3.69236023 -3.2725457
#  -1.35533336]
# After scale features Max value :
#   [ 5.87604314  3.12141754 19.24604012  4.65243788  2.85727268  1.29381298
#   1.65766701]

# %%
new_train
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0        1           5         65.0     8450       1      1         3
# 1        2           0         80.0     9600       1      1         3
# 2        3           5         68.0    11250       1      1         0
# 3        4           6         60.0     9550       1      1         0
# 4        5           5         84.0    14260       1      1         0
# ...    ...         ...          ...      ...     ...    ...       ...
# 1455  1456           5         62.0     7917       1      1         3
# 1456  1457           0         85.0    13175       1      1         3
# 1457  1458           6         66.0     9042       1      1         3
# 1458  1459           0         68.0     9717       1      1         3
# 1459  1460           0         75.0     9937       1      1         3
#
#       LandSlope  OverallQual  OverallCond  ...  SaleType_New  SaleType_Oth  \
# ...

# %% [markdown]
# ### 5.2. Linear Regression
# * we will use linear regression to predict SalesPrice

# %%
X = train.drop(['SalePrice'], axis=1) #independent columns (except ID)
y = train['SalePrice'] #target column (Sales price)

rbst_scaler=RobustScaler()
X_rbst=rbst_scaler.fit_transform(final_train)
test_rbst=rbst_scaler.transform(final_train)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# Train and testing sets
X_train, X_test, y_train, y_test = train_test_split(final_train, np.log(target), test_size=0.2, random_state = 42)

# Linear regression models
linear=LinearRegression()
X_train = X_train["GrLivArea"].values.reshape(-1,1)
linear.fit(X_train, y_train)
print("[First model (GrLivArea)]")
print("Accuracy = "+str(1-linear.score(X_test["GrLivArea"].values.reshape(-1,1), y_test)))
# Out:
# [First model (GrLivArea)]
# Accuracy = 0.5114095241847425

# %%
X_train, X_test, y_train, y_test = train_test_split(final_train, np.log(target), test_size=0.2, random_state = 42)

linear2=LinearRegression()
X_train = X_train["YearBuilt"].values.reshape(-1,1)
linear2.fit(X_train, y_train)
print("[Second model (YearBuilt)]")
print("Accuracy = "+str(1-linear2.score(X_test["YearBuilt"].values.reshape(-1,1), y_test)))
# Out:
# [Second model (YearBuilt)]
# Accuracy = 0.6685673178794727

# %%
X_train, X_test, y_train, y_test = train_test_split(final_train, np.log(target), test_size=0.2, random_state = 42)

linear3=LinearRegression()
X_train = X_train["FullBath"].values.reshape(-1,1)
linear3.fit(X_train, y_train)
print("[Third model (FullBath)]")
print("Accuracy = "+str(1-linear3.score(X_test["FullBath"].values.reshape(-1,1), y_test)))
# Out:
# [Third model (FullBath)]
# Accuracy = 0.598550184066644

# %%
X_train, X_test, y_train, y_test = train_test_split(final_train, np.log(target), test_size=0.2, random_state = 42)

linear4=LinearRegression()
X_train = X_train["GarageArea"].values.reshape(-1,1)
linear4.fit(X_train, y_train)
print("[Fourth model (GarageArea)]")
print("Accuracy = "+str(1-linear4.score(X_test["GarageArea"].values.reshape(-1,1), y_test)))
# Out:
# [Fourth model (GarageArea)]
# Accuracy = 0.6137462876091702

# %%
X_train, X_test, y_train, y_test = train_test_split(final_train, np.log(target), test_size=0.2, random_state = 42)

linear5=LinearRegression()
X_train = X_train["OverallQual"].values.reshape(-1,1)
linear5.fit(X_train, y_train)
print("[Fifth model (OverallQual)]")
print("Accuracy = "+str(1-linear5.score(X_test["OverallQual"].values.reshape(-1,1), y_test)))
# Out:
# [Fifth model (OverallQual)]
# Accuracy = 0.2836369386141957

# %% [markdown]
# ## **6.Evaluation**

# %% [markdown]
# ### 6.1.Regressor

# %%
# regression coefficients
print('Coefficients (GrLivArea) : ', linear.coef_)
print('\nCoefficients (YearBuilt) : ', linear2.coef_)
print('\nCoefficients (FullBath) : ', linear3.coef_)
print('\nCoefficients (GarageArea) : ', linear4.coef_)
print('\nCoefficients (OverallQual) : ', linear4.coef_)
# Out:
# Coefficients (GrLivArea) :  [4.74098611e-05]
#
# Coefficients (YearBuilt) :  [0.00064493]
#
# Coefficients (FullBath) :  [0.03453799]
#
# Coefficients (GarageArea) :  [0.00010203]
#
# Coefficients (OverallQual) :  [0.00010203]

# %% [markdown]
# #### 6.1.1. Statsmodel OLS Regression Results

# %%
model = sm.OLS(target.values, final_train)
re = model.fit()
re.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          9.736e+05
# Date:                Tue, 31 May 2022   Prob (F-statistic):                        0.00
# Time:                        06:27:22   Log-Likelihood:                          729.58
# No. Observations:                1458   AIC:                                     -1439.
# Df Residuals:                    1448   BIC:                                     -1386.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# *   In simple linear regression, the closer the r-squared is to 1, the more useful it is, and the higher the correlation with target features, the higher the usefulness was predicted only by the features.

# %% [markdown]
# ### 6.2.Esemble Learing

# %% [markdown]
# #### 6.2.1. RandomForest, GradientBoosting, XGB

# %%
# RandomForest, GradientBoosting, XGB

kfold = KFold(n_splits=4)
random_state = 1
reg = []

reg.append(RandomForestRegressor(random_state=random_state))
reg.append(GradientBoostingRegressor(random_state=random_state))
reg.append(XGBRegressor(silent=True,random_state=random_state))

reg_results = []

for regre in reg :
    reg_results.append(np.mean(np.sqrt(-cross_val_score(regre, X_rbst, y = target,scoring = 'neg_mean_squared_error',
                                       cv = kfold, n_jobs=-4))))
reg_means = []
reg_std = []
for reg_result in reg_results:
    reg_means.append(reg_result.mean())
    reg_std.append(reg_result.std())
reg_re = pd.DataFrame({"CrossValMeans":reg_means,"CrossValerrors": reg_std})
print(reg_re)
# Out:
#    CrossValMeans  CrossValerrors
# 0       0.152580             0.0
# 1       0.146936             0.0
# 2       0.146141             0.0

# %%
# Gradient boosting 파라미터 튜닝
GBC = GradientBoostingRegressor()
gb_param_grid = {'n_estimators' : [100,200,300],
              'learning_rate': [0.1, 0.05, 0.01],
              'max_depth': [4, 8],
              'min_samples_leaf': [100,150],
              'max_features': [0.3, 0.1] 
              }
gsGBC = GridSearchCV(GBC,param_grid = gb_param_grid, cv=kfold, scoring="neg_mean_squared_error", n_jobs= 4, verbose = 1)
gsGBC.fit(X_rbst,target)
GBC_best = gsGBC.best_estimator_

# 최고 점수
gsGBC.best_score_
# Out:
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# -0.023530157175173042

# %%
# XGBoost 파라미터 튜닝 

XGB = XGBRegressor()
xgb_param_grid = {'learning_rate': [1,0.1,0.01,0.001],
              'n_estimators': [50, 100, 200, 500, 1000],
              'max_depth' : [1,3,5,10,50]}
gsXGB = GridSearchCV(XGB,param_grid = xgb_param_grid, cv=kfold, scoring="neg_mean_squared_error", n_jobs= 4, verbose = 1)
gsXGB.fit(X_rbst,target)
XGB_best = gsXGB.best_estimator_

# 최고 점수
gsXGB.best_score_
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# [06:29:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# -0.02110483943462855

# %%
test_Survived_GBC = pd.Series(GBC_best.predict(test_rbst), name="GBC")
test_Survived_XGB = pd.Series(XGB_best.predict(test_rbst), name="XGB")
ensemble = np.expm1(0.1*test_Survived_GBC + 0.8*test_Survived_XGB )

ensemble_results = pd.concat([test_Survived_XGB,
                              test_Survived_GBC],axis=1)
g= sns.heatmap(ensemble_results.corr(),annot=True)

# %%
result = pd.DataFrame({
    "Id" :test['Id'],
    "SalePrice": ensemble
})
print(result.head())
# Out:
#      Id     SalePrice
# 0  1461  58665.276927
# 1  1462  47729.660933
# 2  1463  61494.949165
# 3  1464  51857.810062
# 4  1465  83518.614988

# %% [markdown]
# * After comparing the correlation between the two models through heatmap, the ensemble modeling was carried out because the two models were highly correlated with each other.

# %% [markdown]
# ### 6.3.Predict vs Actual

# %%
# Features used
features = ["GrLivArea", "MSSubClass", 'LotArea', 'TotRmsAbvGrd', 'OverallQual', 'YearBuilt','YrSold']

# Train and testing sets
X_train, X_test, y_train, y_test = train_test_split(train[features], np.log(train["SalePrice"]), test_size=0.2, random_state = 42)

# %%
def test_model(model, X_train=X_train, y_train=y_train):
    cv = KFold(n_splits = 3, shuffle=True, random_state = 45)
    r2 = make_scorer(r2_score)
    r2_val_score = cross_val_score(model, X_train, y_train, cv=cv, scoring = r2)
    score = [r2_val_score.mean()]
    return score

# %% [markdown]
# #### 6.3.1. Random Forest Regression

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X_train, y_train)
clf = RandomForestRegressor(n_estimators=500, n_jobs=-1)
print("[Random Forest Regressor]")
print(test_model(clf))
clf.fit(X_train1, y_train1)
# Out:
# [Random Forest Regressor]
# [0.8277209375791065]
# RandomForestRegressor(n_estimators=500, n_jobs=-1)

# %%
y_pred = clf.predict(X_test1)

plt.figure(figsize=(10, 5))
plt.scatter(y_test1, y_pred, s=20)
plt.title('Predicted vs. Actual')
plt.xlabel('Actual Sale Price')
plt.ylabel('Predicted Sale Price')

plt.plot([min(y_test1), max(y_test1)], [min(y_test1), max(y_test1)])
plt.tight_layout()
plt.show()

# %% [markdown]
# *   The accuracy was low when predicted simply using linear stress, but accuracy could be increased through ensemble learning and random forest.

# %% [markdown]
# ## **7. Deployment**

# %% [markdown]
# ### 7.1. GitHub Link

# %% [markdown]
# * 곽지우 https://github.com/kwakjiwoo
# * 김동현 https://github.com/eastlighting1
# * 오채영 https://github.com/CHCHAENG
# * 이지연 https://github.com/ZN-Sellena2000

# %% [markdown]
# ### 7.2. Kaggle Link
